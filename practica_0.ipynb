# %% [markdown]
# # Práctica 0 - ROS2
#
# **Alumno:** Villarreal Hinojosa Baruch Alfonso
# **Materia:** [Nombre de la materia]
# **Grupo:** [Tu grupo]
# **Fecha:** [Fecha]

# %% [markdown]
# ## Evidencia
#
# ![Evidencia](evidencia1.jpg)
